# %%
import numpy as np
import pandas as pd
import cv2
import os
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from numpy import savez_compressed
from tqdm import tqdm_notebook as tqdm
from numpy import load
from sklearn.model_selection import train_test_split

# %%
images_path = "./images/"
files = os.listdir(images_path)

# %%
train_files = [i for i in files if "Train" in i]

# %%
print("Train: ", len(train_files))
# Out:
# Train:  1821

# %% [markdown]
# # Load Train CSV data

# %%
train_df = pd.read_csv("train.csv")

# %%
train_df.head(10)
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0
# 5  Train_5        1                  0     0     0
# 6  Train_6        0                  1     0     0
# 7  Train_7        0                  0     0     1
# 8  Train_8        0                  0     0     1
# 9  Train_9        1                  0     0     0

# %%
print("Total: ", len(train_df))
print("Healthy: ",len(train_df[train_df["healthy"] == 1]))
print("Diseased: ",len(train_df[train_df["healthy"] == 0]))
# Out:
# Total:  1821
# Healthy:  516
# Diseased:  1305

# %%
y_dict = train_df.set_index('image_id')['healthy'].to_dict()

# %%
y_dict
# Out:
# {'Train_0': 0,
#  'Train_1': 0,
#  'Train_2': 1,
#  'Train_3': 0,
#  'Train_4': 1,
#  'Train_5': 1,
#  'Train_6': 0,
#  'Train_7': 0,
#  'Train_8': 0,
#  'Train_9': 1,
#  'Train_10': 0,
#  'Train_11': 0,
#  'Train_12': 0,
#  'Train_13': 1,
#  'Train_14': 0,
#  'Train_15': 0,
#  'Train_16': 0,
#  'Train_17': 0,
#  'Train_18': 1,
#  'Train_19': 0,
#  'Train_20': 0,
#  'Train_21': 0,
#  'Train_22': 0,
#  'Train_23': 0,
#  'Train_24': 1,
#  'Train_25': 0,
#  'Train_26': 0,
#  'Train_27': 0,
#  'Train_28': 0,
#  'Train_29': 0,
#  'Train_30': 0,
#  'Train_31': 0,
#  'Train_32': 0,
#  'Train_33': 1,
#  'Train_34': 0,
#  'Train_35': 0,
#  'Train_36': 0,
#  'Train_37': 0,
#  'Train_38': 0,
#  'Train_39': 0,
#  'Train_40': 0,
#  'Train_41': 0,
#  'Train_42': 0,
#  'Train_43': 1,
#  'Train_44': 0,
#  'Train_45': 0,
#  'Train_46': 1,
#  'Train_47': 0,
#  'Train_48': 0,
#  'Train_49': 0,
#  'Train_50': 0,
#  'Train_51': 0,
#  'Train_52': 0,
#  'Train_53': 1,
#  'Train_54': 1,
#  'Train_55': 1,
#  'Train_56': 0,
#  'Train_57': 0,
#  'Train_58': 0,
#  'Train_59': 0,
#  'Train_60': 0,
#  'Train_61': 0,
#  'Train_62': 0,
#  'Train_63': 1,
#  'Train_64': 0,
#  'Train_65': 0,
#  'Train_66': 1,
#  'Train_67': 1,
#  'Train_68': 1,
#  'Train_69': 0,
#  'Train_70': 1,
#  'Train_71': 0,
#  'Train_72': 1,
#  'Train_73': 0,
#  'Train_74': 0,
#  'Train_75': 0,
#  'Train_76': 0,
#  'Train_77': 1,
#  'Train_78': 0,
#  'Train_79': 0,
#  'Train_80': 0,
#  'Train_81': 0,
#  'Train_82': 0,
#  'Train_83': 0,
#  'Train_84': 0,
#  'Train_85': 0,
#  'Train_86': 1,
#  'Train_87': 0,
#  'Train_88': 1,
#  'Train_89': 0,
#  'Train_90': 1,
#  'Train_91': 0,
#  'Train_92': 0,
#  'Train_93': 0,
#  'Train_94': 1,
#  'Train_95': 0,
#  'Train_96': 0,
#  'Train_97': 0,
#  'Train_98': 0,
#  'Train_99': 1,
#  'Train_100': 1,
#  'Train_101': 0,
#  'Train_102': 0,
#  'Train_103': 1,
#  'Train_104': 0,
#  'Train_105': 1,
#  'Train_106': 0,
#  'Train_107': 0,
#  'Train_108': 0,
#  'Train_109': 0,
#  'Train_110': 0,
#  'Train_111': 1,
#  'Train_112': 0,
#  'Train_113': 0,
#  'Train_114': 0,
#  'Train_115': 0,
#  'Train_116': 0,
#  'Train_117': 0,
#  'Train_118': 0,
#  'Train_119': 0,
#  'Train_120': 0,
#  'Train_121': 0,
#  'Train_122': 0,
#  'Train_123': 1,
#  'Train_124': 0,
#  'Train_125': 0,
#  'Train_126': 0,
#  'Train_127': 0,
#  'Train_128': 0,
#  'Train_129': 0,
#  'Train_130': 0,
#  'Train_131': 0,
#  'Train_132': 0,
#  'Train_133': 0,
#  'Train_134': 1,
#  'Train_135': 1,
#  'Train_136': 1,
#  'Train_137': 1,
#  'Train_138': 0,
#  'Train_139': 0,
#  'Train_140': 0,
#  'Train_141': 0,
#  'Train_142': 0,
#  'Train_143': 0,
#  'Train_144': 1,
#  'Train_145': 0,
#  'Train_146': 1,
#  'Train_147': 0,
#  'Train_148': 0,
#  'Train_149': 0,
#  'Train_150': 0,
#  'Train_151': 1,
#  'Train_152': 0,
#  'Train_153': 0,
#  'Train_154': 0,
#  'Train_155': 0,
#  'Train_156': 0,
#  'Train_157': 0,
#  'Train_158': 0,
#  'Train_159': 0,
#  'Train_160': 0,
#  'Train_161': 0,
#  'Train_162': 1,
#  'Train_163': 0,
#  'Train_164': 0,
#  'Train_165': 0,
#  'Train_166': 0,
#  'Train_167': 1,
#  'Train_168': 0,
#  'Train_169': 0,
#  'Train_170': 0,
#  'Train_171': 0,
#  'Train_172': 0,
#  'Train_173': 0,
#  'Train_174': 1,
#  'Train_175': 1,
#  'Train_176': 0,
#  'Train_177': 0,
#  'Train_178': 0,
#  'Train_179': 1,
#  'Train_180': 0,
#  'Train_181': 0,
#  'Train_182': 0,
#  'Train_183': 0,
#  'Train_184': 0,
#  'Train_185': 0,
#  'Train_186': 0,
#  'Train_187': 0,
#  'Train_188': 0,
#  'Train_189': 0,
#  'Train_190': 0,
#  'Train_191': 0,
#  'Train_192': 0,
#  'Train_193': 0,
#  'Train_194': 0,
#  'Train_195': 1,
#  'Train_196': 0,
#  'Train_197': 0,
#  'Train_198': 1,
#  'Train_199': 1,
#  'Train_200': 0,
#  'Train_201': 1,
#  'Train_202': 0,
#  'Train_203': 0,
#  'Train_204': 0,
#  'Train_205': 0,
#  'Train_206': 0,
#  'Train_207': 0,
#  'Train_208': 0,
#  'Train_209': 0,
#  'Train_210': 0,
#  'Train_211': 0,
#  'Train_212': 0,
#  'Train_213': 1,
#  'Train_214': 0,
#  'Train_215': 1,
#  'Train_216': 0,
#  'Train_217': 0,
#  'Train_218': 0,
#  'Train_219': 1,
#  'Train_220': 1,
#  'Train_221': 1,
#  'Train_222': 0,
#  'Train_223': 0,
#  'Train_224': 1,
#  'Train_225': 0,
#  'Train_226': 0,
#  'Train_227': 1,
#  'Train_228': 0,
#  'Train_229': 0,
#  'Train_230': 0,
#  'Train_231': 0,
#  'Train_232': 0,
#  'Train_233': 0,
#  'Train_234': 0,
#  'Train_235': 0,
#  'Train_236': 0,
#  'Train_237': 0,
#  'Train_238': 1,
#  'Train_239': 0,
#  'Train_240': 0,
#  'Train_241': 0,
#  'Train_242': 0,
#  'Train_243': 0,
#  'Train_244': 0,
#  'Train_245': 0,
#  'Train_246': 1,
#  'Train_247': 1,
#  'Train_248': 1,
#  'Train_249': 1,
#  'Train_250': 0,
#  'Train_251': 0,
#  'Train_252': 0,
#  'Train_253': 0,
#  'Train_254': 0,
#  'Train_255': 0,
#  'Train_256': 0,
#  'Train_257': 1,
#  'Train_258': 0,
#  'Train_259': 0,
#  'Train_260': 0,
#  'Train_261': 1,
#  'Train_262': 0,
#  'Train_263': 1,
#  'Train_264': 1,
#  'Train_265': 1,
#  'Train_266': 1,
#  'Train_267': 0,
#  'Train_268': 0,
#  'Train_269': 0,
#  'Train_270': 0,
#  'Train_271': 1,
#  'Train_272': 0,
#  'Train_273': 1,
#  'Train_274': 0,
#  'Train_275': 0,
#  'Train_276': 0,
#  'Train_277': 0,
#  'Train_278': 1,
#  'Train_279': 0,
#  'Train_280': 0,
#  'Train_281': 0,
#  'Train_282': 1,
#  'Train_283': 0,
#  'Train_284': 0,
#  'Train_285': 0,
#  'Train_286': 0,
#  'Train_287': 1,
#  'Train_288': 0,
#  'Train_289': 0,
#  'Train_290': 0,
#  'Train_291': 1,
#  'Train_292': 0,
#  'Train_293': 0,
#  'Train_294': 0,
#  'Train_295': 1,
#  'Train_296': 0,
#  'Train_297': 0,
#  'Train_298': 1,
#  'Train_299': 0,
#  'Train_300': 1,
#  'Train_301': 0,
#  'Train_302': 0,
#  'Train_303': 0,
#  'Train_304': 1,
#  'Train_305': 0,
#  'Train_306': 0,
#  'Train_307': 1,
#  'Train_308': 0,
#  'Train_309': 0,
#  'Train_310': 0,
#  'Train_311': 1,
#  'Train_312': 0,
#  'Train_313': 0,
#  'Train_314': 0,
#  'Train_315': 0,
#  'Train_316': 0,
#  'Train_317': 1,
#  'Train_318': 0,
#  'Train_319': 0,
#  'Train_320': 1,
#  'Train_321': 0,
#  'Train_322': 0,
#  'Train_323': 0,
#  'Train_324': 0,
#  'Train_325': 0,
#  'Train_326': 0,
#  'Train_327': 0,
#  'Train_328': 0,
#  'Train_329': 1,
#  'Train_330': 1,
#  'Train_331': 0,
#  'Train_332': 0,
#  'Train_333': 0,
#  'Train_334': 0,
#  'Train_335': 1,
#  'Train_336': 0,
#  'Train_337': 1,
#  'Train_338': 0,
#  'Train_339': 1,
#  'Train_340': 0,
#  'Train_341': 0,
#  'Train_342': 0,
#  'Train_343': 0,
#  'Train_344': 0,
#  'Train_345': 0,
#  'Train_346': 0,
#  'Train_347': 0,
#  'Train_348': 1,
#  'Train_349': 0,
#  'Train_350': 0,
#  'Train_351': 0,
#  'Train_352': 0,
#  'Train_353': 0,
#  'Train_354': 0,
#  'Train_355': 0,
#  'Train_356': 1,
#  'Train_357': 1,
#  'Train_358': 0,
#  'Train_359': 1,
#  'Train_360': 1,
#  'Train_361': 0,
#  'Train_362': 0,
#  'Train_363': 0,
#  'Train_364': 0,
#  'Train_365': 1,
#  'Train_366': 1,
#  'Train_367': 1,
#  'Train_368': 0,
#  'Train_369': 0,
#  'Train_370': 0,
#  'Train_371': 0,
#  'Train_372': 0,
#  'Train_373': 1,
#  'Train_374': 0,
#  'Train_375': 1,
#  'Train_376': 1,
#  'Train_377': 0,
#  'Train_378': 1,
#  'Train_379': 0,
#  'Train_380': 1,
#  'Train_381': 0,
#  'Train_382': 0,
#  'Train_383': 1,
#  'Train_384': 0,
#  'Train_385': 0,
#  'Train_386': 0,
#  'Train_387': 0,
#  'Train_388': 0,
#  'Train_389': 1,
#  'Train_390': 0,
#  'Train_391': 0,
#  'Train_392': 1,
#  'Train_393': 1,
#  'Train_394': 0,
#  'Train_395': 0,
#  'Train_396': 1,
#  'Train_397': 1,
#  'Train_398': 0,
#  'Train_399': 0,
#  'Train_400': 0,
#  'Train_401': 0,
#  'Train_402': 0,
#  'Train_403': 0,
#  'Train_404': 1,
#  'Train_405': 1,
#  'Train_406': 1,
#  'Train_407': 1,
#  'Train_408': 0,
#  'Train_409': 0,
#  'Train_410': 0,
#  'Train_411': 0,
#  'Train_412': 1,
#  'Train_413': 0,
#  'Train_414': 0,
#  'Train_415': 1,
#  'Train_416': 0,
#  'Train_417': 1,
#  'Train_418': 0,
#  'Train_419': 0,
#  'Train_420': 1,
#  'Train_421': 1,
#  'Train_422': 0,
#  'Train_423': 0,
#  'Train_424': 0,
#  'Train_425': 1,
#  'Train_426': 0,
#  'Train_427': 1,
#  'Train_428': 0,
#  'Train_429': 0,
#  'Train_430': 1,
#  'Train_431': 0,
#  'Train_432': 1,
#  'Train_433': 1,
#  'Train_434': 0,
#  'Train_435': 0,
#  'Train_436': 0,
#  'Train_437': 0,
#  'Train_438': 1,
#  'Train_439': 1,
#  'Train_440': 0,
#  'Train_441': 0,
#  'Train_442': 0,
#  'Train_443': 1,
#  'Train_444': 1,
#  'Train_445': 0,
#  'Train_446': 1,
#  'Train_447': 0,
#  'Train_448': 1,
#  'Train_449': 0,
#  'Train_450': 1,
#  'Train_451': 0,
#  'Train_452': 1,
#  'Train_453': 0,
#  'Train_454': 0,
#  'Train_455': 0,
#  'Train_456': 0,
#  'Train_457': 0,
#  'Train_458': 0,
#  'Train_459': 0,
#  'Train_460': 1,
#  'Train_461': 0,
#  'Train_462': 0,
#  'Train_463': 0,
#  'Train_464': 0,
#  'Train_465': 0,
#  'Train_466': 1,
#  'Train_467': 0,
#  'Train_468': 0,
#  'Train_469': 0,
#  'Train_470': 0,
#  'Train_471': 0,
#  'Train_472': 0,
#  'Train_473': 0,
#  'Train_474': 1,
#  'Train_475': 1,
#  'Train_476': 1,
#  'Train_477': 0,
#  'Train_478': 1,
#  'Train_479': 0,
#  'Train_480': 0,
#  'Train_481': 0,
#  'Train_482': 0,
#  'Train_483': 0,
#  'Train_484': 0,
#  'Train_485': 0,
#  'Train_486': 0,
#  'Train_487': 0,
#  'Train_488': 1,
#  'Train_489': 0,
#  'Train_490': 0,
#  'Train_491': 1,
#  'Train_492': 0,
#  'Train_493': 0,
#  'Train_494': 0,
#  'Train_495': 0,
#  'Train_496': 1,
#  'Train_497': 0,
#  'Train_498': 0,
#  'Train_499': 0,
#  'Train_500': 0,
#  'Train_501': 0,
#  'Train_502': 1,
#  'Train_503': 0,
#  'Train_504': 0,
#  'Train_505': 0,
#  'Train_506': 0,
#  'Train_507': 0,
#  'Train_508': 0,
#  'Train_509': 0,
#  'Train_510': 0,
#  'Train_511': 0,
#  'Train_512': 0,
#  'Train_513': 0,
#  'Train_514': 0,
#  'Train_515': 0,
#  'Train_516': 0,
#  'Train_517': 0,
#  'Train_518': 0,
#  'Train_519': 0,
#  'Train_520': 0,
#  'Train_521': 0,
#  'Train_522': 0,
#  'Train_523': 0,
#  'Train_524': 0,
#  'Train_525': 1,
#  'Train_526': 1,
#  'Train_527': 0,
#  'Train_528': 0,
#  'Train_529': 1,
#  'Train_530': 0,
#  'Train_531': 1,
#  'Train_532': 1,
#  'Train_533': 0,
#  'Train_534': 0,
#  'Train_535': 0,
#  'Train_536': 0,
#  'Train_537': 1,
#  'Train_538': 0,
#  'Train_539': 0,
#  'Train_540': 0,
#  'Train_541': 0,
#  'Train_542': 0,
#  'Train_543': 0,
#  'Train_544': 1,
#  'Train_545': 1,
#  'Train_546': 1,
#  'Train_547': 1,
#  'Train_548': 0,
#  'Train_549': 0,
#  'Train_550': 1,
#  'Train_551': 1,
#  'Train_552': 0,
#  'Train_553': 0,
#  'Train_554': 0,
#  'Train_555': 0,
#  'Train_556': 0,
#  'Train_557': 0,
#  'Train_558': 1,
#  'Train_559': 0,
#  'Train_560': 0,
#  'Train_561': 0,
#  'Train_562': 1,
#  'Train_563': 0,
#  'Train_564': 0,
#  'Train_565': 0,
#  'Train_566': 1,
#  'Train_567': 0,
#  'Train_568': 0,
#  'Train_569': 1,
#  'Train_570': 0,
#  'Train_571': 0,
#  'Train_572': 1,
#  'Train_573': 1,
#  'Train_574': 0,
#  'Train_575': 0,
#  'Train_576': 0,
#  'Train_577': 0,
#  'Train_578': 0,
#  'Train_579': 1,
#  'Train_580': 0,
#  'Train_581': 0,
#  'Train_582': 0,
#  'Train_583': 0,
#  'Train_584': 0,
#  'Train_585': 0,
#  'Train_586': 0,
#  'Train_587': 1,
#  'Train_588': 0,
#  'Train_589': 0,
#  'Train_590': 0,
#  'Train_591': 1,
#  'Train_592': 1,
#  'Train_593': 0,
#  'Train_594': 0,
#  'Train_595': 1,
#  'Train_596': 0,
#  'Train_597': 1,
#  'Train_598': 0,
#  'Train_599': 0,
#  'Train_600': 0,
#  'Train_601': 1,
#  'Train_602': 0,
#  'Train_603': 1,
#  'Train_604': 0,
#  'Train_605': 1,
#  'Train_606': 0,
#  'Train_607': 0,
#  'Train_608': 0,
#  'Train_609': 0,
#  'Train_610': 0,
#  'Train_611': 0,
#  'Train_612': 0,
#  'Train_613': 0,
#  'Train_614': 0,
#  'Train_615': 0,
#  'Train_616': 1,
#  'Train_617': 0,
#  'Train_618': 1,
#  'Train_619': 1,
#  'Train_620': 0,
#  'Train_621': 1,
#  'Train_622': 1,
#  'Train_623': 0,
#  'Train_624': 0,
#  'Train_625': 0,
#  'Train_626': 1,
#  'Train_627': 0,
#  'Train_628': 0,
#  'Train_629': 0,
#  'Train_630': 1,
#  'Train_631': 0,
#  'Train_632': 0,
#  'Train_633': 0,
#  'Train_634': 0,
#  'Train_635': 1,
#  'Train_636': 0,
#  'Train_637': 1,
#  'Train_638': 0,
#  'Train_639': 0,
#  'Train_640': 0,
#  'Train_641': 0,
#  'Train_642': 1,
#  'Train_643': 0,
#  'Train_644': 1,
#  'Train_645': 0,
#  'Train_646': 1,
#  'Train_647': 0,
#  'Train_648': 1,
#  'Train_649': 0,
#  'Train_650': 1,
#  'Train_651': 0,
#  'Train_652': 0,
#  'Train_653': 0,
#  'Train_654': 0,
#  'Train_655': 0,
#  'Train_656': 0,
#  'Train_657': 1,
#  'Train_658': 0,
#  'Train_659': 0,
#  'Train_660': 1,
#  'Train_661': 0,
#  'Train_662': 0,
#  'Train_663': 0,
#  'Train_664': 0,
#  'Train_665': 1,
#  'Train_666': 0,
#  'Train_667': 0,
#  'Train_668': 0,
#  'Train_669': 0,
#  'Train_670': 0,
#  'Train_671': 1,
#  'Train_672': 0,
#  'Train_673': 0,
#  'Train_674': 0,
#  'Train_675': 1,
#  'Train_676': 1,
#  'Train_677': 0,
#  'Train_678': 1,
#  'Train_679': 1,
#  'Train_680': 0,
#  'Train_681': 0,
#  'Train_682': 0,
#  'Train_683': 0,
#  'Train_684': 1,
#  'Train_685': 1,
#  'Train_686': 0,
#  'Train_687': 0,
#  'Train_688': 0,
#  'Train_689': 0,
#  'Train_690': 0,
#  'Train_691': 1,
#  'Train_692': 0,
#  'Train_693': 0,
#  'Train_694': 1,
#  'Train_695': 0,
#  'Train_696': 0,
#  'Train_697': 0,
#  'Train_698': 0,
#  'Train_699': 0,
#  'Train_700': 0,
#  'Train_701': 1,
#  'Train_702': 0,
#  'Train_703': 1,
#  'Train_704': 1,
#  'Train_705': 0,
#  'Train_706': 0,
#  'Train_707': 0,
#  'Train_708': 0,
#  'Train_709': 0,
#  'Train_710': 1,
#  'Train_711': 1,
#  'Train_712': 0,
#  'Train_713': 0,
#  'Train_714': 0,
#  'Train_715': 0,
#  'Train_716': 0,
#  'Train_717': 0,
#  'Train_718': 0,
#  'Train_719': 0,
#  'Train_720': 1,
#  'Train_721': 0,
#  'Train_722': 0,
#  'Train_723': 0,
#  'Train_724': 0,
#  'Train_725': 1,
#  'Train_726': 0,
#  'Train_727': 0,
#  'Train_728': 0,
#  'Train_729': 0,
#  'Train_730': 1,
#  'Train_731': 1,
#  'Train_732': 0,
#  'Train_733': 0,
#  'Train_734': 0,
#  'Train_735': 0,
#  'Train_736': 0,
#  'Train_737': 1,
#  'Train_738': 0,
#  'Train_739': 0,
#  'Train_740': 0,
#  'Train_741': 0,
#  'Train_742': 0,
#  'Train_743': 0,
#  'Train_744': 0,
#  'Train_745': 0,
#  'Train_746': 1,
#  'Train_747': 1,
#  'Train_748': 0,
#  'Train_749': 0,
#  'Train_750': 0,
#  'Train_751': 0,
#  'Train_752': 1,
#  'Train_753': 1,
#  'Train_754': 0,
#  'Train_755': 1,
#  'Train_756': 0,
#  'Train_757': 0,
#  'Train_758': 0,
#  'Train_759': 0,
#  'Train_760': 0,
#  'Train_761': 1,
#  'Train_762': 0,
#  'Train_763': 0,
#  'Train_764': 0,
#  'Train_765': 0,
#  'Train_766': 0,
#  'Train_767': 0,
#  'Train_768': 1,
#  'Train_769': 1,
#  'Train_770': 0,
#  'Train_771': 0,
#  'Train_772': 1,
#  'Train_773': 1,
#  'Train_774': 1,
#  'Train_775': 0,
#  'Train_776': 1,
#  'Train_777': 1,
#  'Train_778': 0,
#  'Train_779': 0,
#  'Train_780': 0,
#  'Train_781': 1,
#  'Train_782': 1,
#  'Train_783': 0,
#  'Train_784': 0,
#  'Train_785': 0,
#  'Train_786': 1,
#  'Train_787': 0,
#  'Train_788': 1,
#  'Train_789': 0,
#  'Train_790': 0,
#  'Train_791': 1,
#  'Train_792': 0,
#  'Train_793': 0,
#  'Train_794': 1,
#  'Train_795': 0,
#  'Train_796': 0,
#  'Train_797': 0,
#  'Train_798': 0,
#  'Train_799': 0,
#  'Train_800': 1,
#  'Train_801': 1,
#  'Train_802': 1,
#  'Train_803': 0,
#  'Train_804': 0,
#  'Train_805': 1,
#  'Train_806': 0,
#  'Train_807': 1,
#  'Train_808': 0,
#  'Train_809': 1,
#  'Train_810': 0,
#  'Train_811': 1,
#  'Train_812': 1,
#  'Train_813': 0,
#  'Train_814': 0,
#  'Train_815': 1,
#  'Train_816': 0,
#  'Train_817': 1,
#  'Train_818': 0,
#  'Train_819': 0,
#  'Train_820': 0,
#  'Train_821': 0,
#  'Train_822': 0,
#  'Train_823': 0,
#  'Train_824': 0,
#  'Train_825': 0,
#  'Train_826': 1,
#  'Train_827': 0,
#  'Train_828': 0,
#  'Train_829': 0,
#  'Train_830': 0,
#  'Train_831': 0,
#  'Train_832': 0,
#  'Train_833': 1,
#  'Train_834': 1,
#  'Train_835': 1,
#  'Train_836': 0,
#  'Train_837': 0,
#  'Train_838': 0,
#  'Train_839': 1,
#  'Train_840': 0,
#  'Train_841': 0,
#  'Train_842': 0,
#  'Train_843': 0,
#  'Train_844': 0,
#  'Train_845': 0,
#  'Train_846': 0,
#  'Train_847': 0,
#  'Train_848': 0,
#  'Train_849': 1,
#  'Train_850': 1,
#  'Train_851': 0,
#  'Train_852': 0,
#  'Train_853': 0,
#  'Train_854': 0,
#  'Train_855': 0,
#  'Train_856': 0,
#  'Train_857': 0,
#  'Train_858': 0,
#  'Train_859': 0,
#  'Train_860': 0,
#  'Train_861': 0,
#  'Train_862': 0,
#  'Train_863': 1,
#  'Train_864': 1,
#  'Train_865': 0,
#  'Train_866': 1,
#  'Train_867': 0,
#  'Train_868': 0,
#  'Train_869': 0,
#  'Train_870': 0,
#  'Train_871': 0,
#  'Train_872': 1,
#  'Train_873': 0,
#  'Train_874': 0,
#  'Train_875': 0,
#  'Train_876': 0,
#  'Train_877': 1,
#  'Train_878': 0,
#  'Train_879': 0,
#  'Train_880': 1,
#  'Train_881': 1,
#  'Train_882': 1,
#  'Train_883': 0,
#  'Train_884': 0,
#  'Train_885': 1,
#  'Train_886': 0,
#  'Train_887': 1,
#  'Train_888': 0,
#  'Train_889': 0,
#  'Train_890': 1,
#  'Train_891': 0,
#  'Train_892': 0,
#  'Train_893': 1,
#  'Train_894': 0,
#  'Train_895': 1,
#  'Train_896': 1,
#  'Train_897': 1,
#  'Train_898': 0,
#  'Train_899': 0,
#  'Train_900': 0,
#  'Train_901': 1,
#  'Train_902': 0,
#  'Train_903': 1,
#  'Train_904': 0,
#  'Train_905': 0,
#  'Train_906': 0,
#  'Train_907': 1,
#  'Train_908': 1,
#  'Train_909': 1,
#  'Train_910': 0,
#  'Train_911': 0,
#  'Train_912': 0,
#  'Train_913': 0,
#  'Train_914': 1,
#  'Train_915': 1,
#  'Train_916': 0,
#  'Train_917': 0,
#  'Train_918': 1,
#  'Train_919': 1,
#  'Train_920': 0,
#  'Train_921': 1,
#  'Train_922': 0,
#  'Train_923': 1,
#  'Train_924': 1,
#  'Train_925': 0,
#  'Train_926': 0,
#  'Train_927': 0,
#  'Train_928': 0,
#  'Train_929': 1,
#  'Train_930': 0,
#  'Train_931': 0,
#  'Train_932': 0,
#  'Train_933': 0,
#  'Train_934': 1,
#  'Train_935': 1,
#  'Train_936': 0,
#  'Train_937': 1,
#  'Train_938': 0,
#  'Train_939': 1,
#  'Train_940': 0,
#  'Train_941': 0,
#  'Train_942': 1,
#  'Train_943': 0,
#  'Train_944': 0,
#  'Train_945': 0,
#  'Train_946': 0,
#  'Train_947': 1,
#  'Train_948': 1,
#  'Train_949': 0,
#  'Train_950': 0,
#  'Train_951': 1,
#  'Train_952': 1,
#  'Train_953': 1,
#  'Train_954': 0,
#  'Train_955': 0,
#  'Train_956': 1,
#  'Train_957': 0,
#  'Train_958': 1,
#  'Train_959': 1,
#  'Train_960': 1,
#  'Train_961': 1,
#  'Train_962': 0,
#  'Train_963': 1,
#  'Train_964': 0,
#  'Train_965': 0,
#  'Train_966': 1,
#  'Train_967': 0,
#  'Train_968': 1,
#  'Train_969': 1,
#  'Train_970': 0,
#  'Train_971': 0,
#  'Train_972': 0,
#  'Train_973': 0,
#  'Train_974': 0,
#  'Train_975': 0,
#  'Train_976': 0,
#  'Train_977': 1,
#  'Train_978': 0,
#  'Train_979': 1,
#  'Train_980': 1,
#  'Train_981': 1,
#  'Train_982': 0,
#  'Train_983': 1,
#  'Train_984': 0,
#  'Train_985': 0,
#  'Train_986': 0,
#  'Train_987': 0,
#  'Train_988': 0,
#  'Train_989': 1,
#  'Train_990': 0,
#  'Train_991': 0,
#  'Train_992': 0,
#  'Train_993': 0,
#  'Train_994': 0,
#  'Train_995': 0,
#  'Train_996': 0,
#  'Train_997': 0,
#  'Train_998': 0,
#  'Train_999': 0,
#  ...}

# %%
size = (180,120)

# %% [markdown]
# # Load Train Image data

# %%
def save_tarin_images_as_list(train_files, images_path, y_dict, size):
    data_list = list()
    label_list = list()
    for file in tqdm(train_files):
        path = images_path + file
        pixels = load_img(path, target_size= size)
        pixels = img_to_array(pixels)
        data_list.append(pixels)
        label_list.append(y_dict[file.split(".")[0]])
    return [data_list,label_list]

# %%
data = save_tarin_images_as_list(train_files, images_path, y_dict, size)
# Out:
# HBox(children=(IntProgress(value=0, max=1821), HTML(value='')))

# %%
X = data[0]
y = data[1]

# %%
filename = 'PestData_Train.npz'
savez_compressed(filename, X, np.array([[i] for i in y]))
print('Saved dataset: ', filename)
# Out:
# Saved dataset:  PestData_Train.npz

# %% [markdown]
# # Build CNN model

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

# %%
model = Sequential()
model.add(Conv2D(16, (3, 3), input_shape=(size[0], size[1], 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(16, (3, 3)))
model.add(Activation('relu'))

# the model so far outputs 3D feature maps (height, width, features)

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(16))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 178, 118, 16)      448
# _________________________________________________________________
# activation_21 (Activation)   (None, 178, 118, 16)      0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 89, 59, 16)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 87, 57, 32)        4640
# _________________________________________________________________
# activation_22 (Activation)   (None, 87, 57, 32)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 43, 28, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 41, 26, 32)        9248
# _________________________________________________________________
# activation_23 (Activation)   (None, 41, 26, 32)        0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 20, 13, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 18, 11, 16)        4624
# _________________________________________________________________
# activation_24 (Activation)   (None, 18, 11, 16)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 3168)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                50704
# _________________________________________________________________
# activation_25 (Activation)   (None, 16)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 17
# _________________________________________________________________
# activation_26 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 69,681
# Trainable params: 69,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %% [markdown]
# # Setup for Training

# %%
data = load("PestData_Train.npz")
X, y = data['arr_0'],data['arr_1']

# %%
print(X.shape)
print(y.shape)
# Out:
# (1821, 180, 120, 3)
# (1821, 1)

# %%
X = np.array(X)
y = np.array(y)
# Normalizing X values between 0 to 1.
X = X.astype('float32')
X /= np.max(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=36)

# %%
from tensorflow.python.keras.callbacks import ModelCheckpoint
filepath="CNN_weights.h5"
checkpoint = ModelCheckpoint(filepath, monitor="val_acc", verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
model.fit(X_train, y_train, epochs=16, batch_size=16, callbacks=callbacks_list, validation_data=(X_test, y_test))
# Out:
# Train on 1274 samples, validate on 547 samples
# Epoch 1/16
# 1274/1274 [==============================] - 30s 23ms/step - loss: 0.6162 - acc: 0.7080 - val_loss: 0.5889 - val_acc: 0.7093
#
# Epoch 00001: val_acc improved from -inf to 0.70932, saving model to CNN_weights.h5
# Epoch 2/16
# 1274/1274 [==============================] - 31s 24ms/step - loss: 0.5857 - acc: 0.7284 - val_loss: 0.5791 - val_acc: 0.7258
#
# Epoch 00002: val_acc improved from 0.70932 to 0.72578, saving model to CNN_weights.h5
# Epoch 3/16
# 1274/1274 [==============================] - 29s 23ms/step - loss: 0.5635 - acc: 0.7355 - val_loss: 0.5595 - val_acc: 0.7130
#
# Epoch 00003: val_acc did not improve from 0.72578
# Epoch 4/16
# 1274/1274 [==============================] - 33s 26ms/step - loss: 0.5432 - acc: 0.7527 - val_loss: 0.5547 - val_acc: 0.7349
#
# Epoch 00004: val_acc improved from 0.72578 to 0.73492, saving model to CNN_weights.h5
# Epoch 5/16
# 1274/1274 [==============================] - 31s 24ms/step - loss: 0.5026 - acc: 0.7810 - val_loss: 0.5598 - val_acc: 0.7367
#
# Epoch 00005: val_acc improved from 0.73492 to 0.73675, saving model to CNN_weights.h5
# Epoch 6/16
# 1274/1274 [==============================] - 29s 23ms/step - loss: 0.4797 - acc: 0.7857 - val_loss: 0.5489 - val_acc: 0.7331
#
# Epoch 00006: val_acc did not improve from 0.73675
# Epoch 7/16
# 1274/1274 [==============================] - 28s 22ms/step - loss: 0.4464 - acc: 0.7951 - val_loss: 0.6909 - val_acc: 0.6143
#
# Epoch 00007: val_acc did not improve from 0.73675
# Epoch 8/16
# 1274/1274 [==============================] - 26s 21ms/step - loss: 0.4103 - acc: 0.8187 - val_loss: 0.5157 - val_acc: 0.7331
#
# Epoch 00008: val_acc did not improve from 0.73675
# Epoch 9/16
# 1274/1274 [==============================] - 27s 21ms/step - loss: 0.3669 - acc: 0.8359 - val_loss: 0.5217 - val_acc: 0.7276
#
# Epoch 00009: val_acc did not improve from 0.73675
# Epoch 10/16
# 1274/1274 [==============================] - 29s 23ms/step - loss: 0.3127 - acc: 0.8650 - val_loss: 0.6132 - val_acc: 0.7770
#
# Epoch 00010: val_acc improved from 0.73675 to 0.77697, saving model to CNN_weights.h5
# Epoch 11/16
# 1274/1274 [==============================] - 29s 23ms/step - loss: 0.2816 - acc: 0.8830 - val_loss: 0.5509 - val_acc: 0.7495
#
# Epoch 00011: val_acc did not improve from 0.77697
# Epoch 12/16
# 1274/1274 [==============================] - 26s 21ms/step - loss: 0.2443 - acc: 0.8995 - val_loss: 0.7474 - val_acc: 0.7532
#
# Epoch 00012: val_acc did not improve from 0.77697
# Epoch 13/16
# 1274/1274 [==============================] - 28s 22ms/step - loss: 0.2087 - acc: 0.9168 - val_loss: 0.6307 - val_acc: 0.7678
#
# Epoch 00013: val_acc did not improve from 0.77697
# Epoch 14/16
# 1274/1274 [==============================] - 33s 26ms/step - loss: 0.1823 - acc: 0.9333 - val_loss: 0.6496 - val_acc: 0.7879
#
# Epoch 00014: val_acc improved from 0.77697 to 0.78793, saving model to CNN_weights.h5
# Epoch 15/16
# 1274/1274 [==============================] - 27s 21ms/step - loss: 0.1428 - acc: 0.9364 - val_loss: 0.6449 - val_acc: 0.7934
#
# Epoch 00015: val_acc improved from 0.78793 to 0.79342, saving model to CNN_weights.h5
# Epoch 16/16
# 1274/1274 [==============================] - 27s 21ms/step - loss: 0.1270 - acc: 0.9553 - val_loss: 0.8929 - val_acc: 0.7331
#
# Epoch 00016: val_acc did not improve from 0.79342

# %%
# serialize model to JSON
model_json = model.to_json()
with open("CNN_model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("CNN_model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # Testing CNN model

# %%
# load json and create model
from tensorflow.python.keras.models import model_from_json

json_file = open('CNN_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights("CNN_weights.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
# evaluate loaded model on test data
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

print("Test data")
score = model.evaluate(X_test, y_test, verbose=1)
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# Test data
# 547/547 [==============================] - 3s 5ms/sample - loss: 0.6449 - acc: 0.7934
# acc: 79.34%

# %%
y_preds = model.predict(X_test, verbose=1)
y_preds.shape
# Out:
# 547/547 [==============================] - 3s 5ms/sample
# (547, 1)

# %%
y_preds[:10]
# Out:
# array([[5.1106846e-01],
#        [9.3845129e-03],
#        [3.3378601e-06],
#        [8.6456537e-05],
#        [2.3318738e-01],
#        [0.0000000e+00],
#        [5.6624413e-07],
#        [8.7640584e-03],
#        [1.1214614e-04],
#        [1.0565817e-03]], dtype=float32)

# %%
preds = model.predict_classes(X_test, verbose=1)
preds.shape
# Out:
# 547/547 [==============================] - 3s 5ms/sample
# (547, 1)

# %%
model.predict_classes(X_test[10].reshape(-1,180,120,3))[0][0]
# Out:
# 0

# %%
print("Actual healthy: ",len(y_test[y_test == 1]))
print("Predicted healthy: ",len(preds[preds == 1]))
# Out:
# Actual healthy:  159
# Predicted healthy:  120

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, preds, target_names=['Non-healthy', 'Healthy']))
# Out:
#               precision    recall  f1-score   support
#
#  Non-healthy       0.82      0.90      0.86       388
#      Healthy       0.69      0.52      0.59       159
#
#    micro avg       0.79      0.79      0.79       547
#    macro avg       0.76      0.71      0.73       547
# weighted avg       0.78      0.79      0.78       547

# %% [markdown]
# # Final Model in Use

# %%
from keras.preprocessing.image import img_to_array
import cv2 
from tensorflow.python.keras.models import model_from_json

def make_predict_CNN(image, size):
    X = cv2.resize(image, size) 
    X = img_to_array(X)
    X = np.array(X).reshape(-1, size[0], size[1], 3)
    X = X.astype('float32')
    X /= 255
    
    json_file = open('CNN_model.json', 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)
    model.load_weights("CNN_weights.h5")

    res = model.predict_classes(X)[0][0]
    
    return res

# %%
size = (180, 120)

image = cv2.imread("./images/Train_11.jpg", 1) 
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
res = make_predict_CNN(image, size)

if res == 0:
    print("Not healthy")
else:
    print("Healthy")
# Out:
# Healthy
